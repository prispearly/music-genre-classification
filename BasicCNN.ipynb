# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models # add models to the list
from torchvision.utils import make_grid
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import os
from PIL import Image
from IPython.display import display

# Filter harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# try to get one of the images inside the file
with Image.open('wavelets/train/rock/11.png') as im:
    display(im)
    print(im.size)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=432x288 at 0x24827D55940>
# (432, 288)

# %%
transform = transforms.ToTensor()
root ="wavelets"

train_data = datasets.ImageFolder(os.path.join(root,"train"), transform= transform)
test_data = datasets.ImageFolder(os.path.join(root, "test"), transform = transform)

torch.manual_seed(30)

train_loader = DataLoader(train_data, batch_size=10,shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=False)

class_names = train_data.classes

# %%
class_names
# Out:
# ['blues',
#  'classical',
#  'country',
#  'disco',
#  'hiphop',
#  'jazz',
#  'metal',
#  'pop',
#  'reggae',
#  'rock']

# %%
len(train_data)
# Out:
# 599

# %%
len(test_data)
# Out:
# 400

# %%
for images, labels in train_loader:
    break
    

print('Labels: ', labels.numpy())
print('Class: ',*np.array([class_names[i] for i in labels]))

im = make_grid(images, nrow=5)
plt.figure(figsize=(10,4))
plt.imshow(np.transpose(im.numpy(),(1,2,0)))
# Out:
# Labels:  [1 3 5 4 3 1 4 5 2 2]
# Class:  classical disco jazz hiphop disco classical hiphop jazz country country

# %%
images[0].shape
# Out:
# torch.Size([3, 288, 432])

# %%
print((((288-2)/2)-2)/2)
print(((430/2)-2)/2)
class ConvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5, 1)  
        self.conv2 = nn.Conv2d(6, 16, 3, 1)
        self.fc1 = nn.Linear(70*106*16, 120)   
        self.fc2 = nn.Linear(120,84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1,70*106*16) # flatten
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        return F.log_softmax(X, dim=1)
# Out:
# 70.5
# 106.5

# %%
model = ConvolutionalNetwork()
model
# Out:
# ConvolutionalNetwork(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=118720, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
for param in model.parameters():
    print(param.numel())
# Out:
# 450
# 6
# 864
# 16
# 14246400
# 120
# 10080
# 84
# 840
# 10

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.001) ## stochiastic gradient descent

# %%
import time
start_time = time.time()

epochs = 5

max_trn_batch = 800
max_tst_batch = 300

train_losses = []
test_losses = []
train_correct = []
test_correct = []

for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        
        # Limit the number of batches
        if b == max_trn_batch:
            break
        b+=1
        
        # Apply the model
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print interim results
        if b%10 == 0:
            print(f'epoch: {i:4}  batch: {b:4} [{10*b:6}/600]  loss: {loss.item():10.8f}  \
accuracy: {trn_corr.item()*100/(10*b):7.3f}%')

    train_losses.append(loss)
    train_correct.append(trn_corr)

    # Run the testing batches
    with torch.no_grad():
        for b, (X_test, y_test) in enumerate(test_loader):
            # Limit the number of batches
            if b == max_tst_batch:
                break

            # Apply the model
            y_val = model(X_test)

            # Tally the number of correct predictions
            predicted = torch.max(y_val.data, 1)[1] 
            tst_corr += (predicted == y_test).sum()

    loss = criterion(y_val, y_test)
    test_losses.append(loss)
    test_correct.append(tst_corr)

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:    0  batch:   10 [   100/600]  loss: 2.42471123  accuracy:   9.000%
# epoch:    0  batch:   20 [   200/600]  loss: 2.29428244  accuracy:   9.500%
# epoch:    0  batch:   30 [   300/600]  loss: 2.26552153  accuracy:   8.333%
# epoch:    0  batch:   40 [   400/600]  loss: 2.36732483  accuracy:   8.750%
# epoch:    0  batch:   50 [   500/600]  loss: 2.25768685  accuracy:  10.800%
# epoch:    0  batch:   60 [   600/600]  loss: 2.15335155  accuracy:  13.333%
# epoch:    1  batch:   10 [   100/600]  loss: 2.06135416  accuracy:  17.000%
# epoch:    1  batch:   20 [   200/600]  loss: 1.96478438  accuracy:  23.000%
# epoch:    1  batch:   30 [   300/600]  loss: 2.23760414  accuracy:  22.667%
# epoch:    1  batch:   40 [   400/600]  loss: 2.01415396  accuracy:  22.500%
# epoch:    1  batch:   50 [   500/600]  loss: 2.17859077  accuracy:  24.400%
# epoch:    1  batch:   60 [   600/600]  loss: 1.79854345  accuracy:  25.833%
# epoch:    2  batch:   10 [   100/600]  loss: 1.12457716  accuracy:  47.000%
# epoch:    2  batch:   20 [   200/600]  loss: 1.66887319  accuracy:  48.000%
# epoch:    2  batch:   30 [   300/600]  loss: 1.51581466  accuracy:  42.667%
# epoch:    2  batch:   40 [   400/600]  loss: 1.17072630  accuracy:  42.750%
# epoch:    2  batch:   50 [   500/600]  loss: 1.99359226  accuracy:  42.400%
# epoch:    2  batch:   60 [   600/600]  loss: 1.35735762  accuracy:  43.667%
# epoch:    3  batch:   10 [   100/600]  loss: 1.36156487  accuracy:  52.000%
# epoch:    3  batch:   20 [   200/600]  loss: 1.04935801  accuracy:  62.000%
# epoch:    3  batch:   30 [   300/600]  loss: 1.35552621  accuracy:  62.000%
# epoch:    3  batch:   40 [   400/600]  loss: 0.90552968  accuracy:  63.750%
# epoch:    3  batch:   50 [   500/600]  loss: 1.73050535  accuracy:  64.000%
# epoch:    3  batch:   60 [   600/600]  loss: 1.13161063  accuracy:  63.333%
# epoch:    4  batch:   10 [   100/600]  loss: 0.37114996  accuracy:  90.000%
# epoch:    4  batch:   20 [   200/600]  loss: 0.87766314  accuracy:  85.000%
# epoch:    4  batch:   30 [   300/600]  loss: 0.80377275  accuracy:  82.333%
# epoch:    4  batch:   40 [   400/600]  loss: 1.07538772  accuracy:  79.750%
# epoch:    4  batch:   50 [   500/600]  loss: 0.76810825  accuracy:  81.400%
# epoch:    4  batch:   60 [   600/600]  loss: 0.44196492  accuracy:  81.500%
#
# Duration: 65 seconds

# %%
torch.save(model.state_dict(), 'CNN Model')

# %%
plt.plot(train_losses, label='training loss')
plt.plot(test_losses, label='validation loss')
plt.title('Loss at the end of each epoch')
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22220/3759129106.py in <module>
# ----> 1 plt.plot(train_losses, label='training loss')
#       2 plt.plot(test_losses, label='validation loss')
#       3 plt.title('Loss at the end of each epoch')
#       4 plt.legend();
#       5
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     491             y = _check_1d(xy[1])
#     492         else:
# --> 493             x, y = index_of(xy[-1])
#     494
#     495         if self.axes.xaxis is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in index_of(y)
#    1685         pass
#    1686     try:
# -> 1687         y = _check_1d(y)
#    1688     except (np.VisibleDeprecationWarning, ValueError):
#    1689         # NumPy 1.19 will warn on ragged input, and we can't actually use it.
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _check_1d(x)
#    1337     """Convert scalars to 1D arrays; pass-through arrays as is."""
#    1338     if not hasattr(x, 'shape') or len(x.shape) < 1:
# -> 1339         return np.atleast_1d(x)
#    1340     else:
#    1341         try:
#
# <__array_function__ internals> in atleast_1d(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\shape_base.py in atleast_1d(*arys)
#      64     res = []
#      65     for ary in arys:
# ---> 66         ary = asanyarray(ary)
#      67         if ary.ndim == 0:
#      68             result = ary.reshape(1)
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asanyarray(a, dtype, order, like)
#     169         return _asanyarray_with_like(a, dtype=dtype, order=order, like=like)
#     170
# --> 171     return array(a, dtype, copy=False, order=order, subok=True)
#     172
#     173
#
# ~\anaconda3\lib\site-packages\torch\_tensor.py in __array__(self, dtype)
#     730             return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     731         if dtype is None:
# --> 732             return self.numpy()
#     733         else:
#     734             return self.numpy().astype(dtype, copy=False)
#
# RuntimeError: Can't call numpy() on Tensor that requires grad. Use tensor.detach().numpy() instead.
