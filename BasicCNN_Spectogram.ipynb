# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models # add models to the list
from torchvision.utils import make_grid
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import os
from PIL import Image
from IPython.display import display

# Filter harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# try to get one of the images inside the file
with Image.open('spectrogram/train/rock/11.png') as im:
    display(im)
    print(im.size)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=432x288 at 0x24A6913EF70>
# (432, 288)

# %%
transform = transforms.ToTensor()
root ="spectrogram"

train_data = datasets.ImageFolder(os.path.join(root,"train"), transform= transform)
test_data = datasets.ImageFolder(os.path.join(root, "test"), transform = transform)

torch.manual_seed(30)

train_loader = DataLoader(train_data, batch_size=10,shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=False)

class_names = train_data.classes

# %%
class_names
# Out:
# ['blues',
#  'classical',
#  'country',
#  'disco',
#  'hiphop',
#  'jazz',
#  'metal',
#  'pop',
#  'reggae',
#  'rock']

# %%
len(train_data)
# Out:
# 599

# %%
len(test_data)
# Out:
# 400

# %%
for images, labels in train_loader:
    break
    
print('Labels: ', labels.numpy())
print('Class: ',*np.array([class_names[i] for i in labels]))

im = make_grid(images, nrow=5)
plt.figure(figsize=(10,4))
plt.imshow(np.transpose(im.numpy(),(1,2,0)))
# Out:
# Labels:  [1 3 5 4 3 1 4 5 2 2]
# Class:  classical disco jazz hiphop disco classical hiphop jazz country country

# %%
images[0].shape
# Out:
# torch.Size([3, 288, 432])

# %%
print((((288-2)/2)-2)/2)
print(((430/2)-2)/2)
class ConvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5, 1)  
        self.conv2 = nn.Conv2d(6, 16, 3, 1)
        self.fc1 = nn.Linear(70*106*16, 120)   
        self.fc2 = nn.Linear(120,84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1,70*106*16) # flatten
        X = F.dropout(X,p=0.2)
        X = F.relu(self.fc1(X))
        X = F.dropout(X,p=0.2)
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        return F.log_softmax(X, dim=1)
# Out:
# 70.5
# 106.5

# %%
model = ConvolutionalNetwork()
model
# Out:
# ConvolutionalNetwork(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=118720, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
for param in model.parameters():
    print(param.numel())
# Out:
# 450
# 6
# 864
# 16
# 14246400
# 120
# 10080
# 84
# 840
# 10

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.001) ## stochiastic gradient descent

# %%
import time
start_time = time.time()

epochs = 50

max_trn_batch = 800
max_tst_batch = 300

train_losses = []
test_losses = []
train_correct = []
test_correct = []

for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        
        # Limit the number of batches
        if b == max_trn_batch:
            break
        b+=1
        
        # Apply the model
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print interim results
        if b%10 == 0:
            print(f'epoch: {i:5}  batch:{b:6} [{10*b:6}/600]  loss: {loss.item():10.8f}  \
accuracy: {trn_corr.item()*100/(10*b):7.3f}%')

    train_losses.append(loss.detach().numpy())
    train_correct.append(trn_corr)

    # Run the testing batches
    with torch.no_grad():
        for b, (X_test, y_test) in enumerate(test_loader):
            # Limit the number of batches
            if b == max_tst_batch:
                break

            # Apply the model
            y_val = model(X_test)

            # Tally the number of correct predictions
            predicted = torch.max(y_val.data, 1)[1] 
            tst_corr += (predicted == y_test).sum()

    loss = criterion(y_val, y_test)
    test_losses.append(loss)
    test_correct.append(tst_corr)

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:     0  batch:    10 [   100/600]  loss: 2.39045238  accuracy:   8.000%
# epoch:     0  batch:    20 [   200/600]  loss: 2.30545878  accuracy:  11.000%
# epoch:     0  batch:    30 [   300/600]  loss: 2.27753687  accuracy:  11.667%
# epoch:     0  batch:    40 [   400/600]  loss: 2.34735632  accuracy:  13.500%
# epoch:     0  batch:    50 [   500/600]  loss: 2.17971253  accuracy:  14.600%
# epoch:     0  batch:    60 [   600/600]  loss: 1.93125510  accuracy:  15.333%
# epoch:     1  batch:    10 [   100/600]  loss: 1.90061092  accuracy:  24.000%
# epoch:     1  batch:    20 [   200/600]  loss: 2.20763922  accuracy:  22.000%
# epoch:     1  batch:    30 [   300/600]  loss: 2.17040253  accuracy:  23.000%
# epoch:     1  batch:    40 [   400/600]  loss: 2.11019111  accuracy:  26.750%
# epoch:     1  batch:    50 [   500/600]  loss: 1.63559937  accuracy:  27.200%
# epoch:     1  batch:    60 [   600/600]  loss: 2.41857934  accuracy:  26.833%
# epoch:     2  batch:    10 [   100/600]  loss: 2.11433530  accuracy:  30.000%
# epoch:     2  batch:    20 [   200/600]  loss: 1.95577300  accuracy:  29.500%
# epoch:     2  batch:    30 [   300/600]  loss: 2.05397534  accuracy:  29.000%
# epoch:     2  batch:    40 [   400/600]  loss: 1.97152042  accuracy:  28.750%
# epoch:     2  batch:    50 [   500/600]  loss: 1.79852426  accuracy:  27.800%
# epoch:     2  batch:    60 [   600/600]  loss: 1.55695724  accuracy:  28.500%
# epoch:     3  batch:    10 [   100/600]  loss: 1.79594231  accuracy:  32.000%
# epoch:     3  batch:    20 [   200/600]  loss: 1.69715059  accuracy:  28.000%
# epoch:     3  batch:    30 [   300/600]  loss: 2.03126669  accuracy:  28.000%
# epoch:     3  batch:    40 [   400/600]  loss: 1.95007765  accuracy:  30.250%
# epoch:     3  batch:    50 [   500/600]  loss: 2.04613876  accuracy:  31.000%
# epoch:     3  batch:    60 [   600/600]  loss: 1.90700853  accuracy:  29.000%
# epoch:     4  batch:    10 [   100/600]  loss: 1.84381890  accuracy:  28.000%
# epoch:     4  batch:    20 [   200/600]  loss: 1.71852779  accuracy:  29.500%
# epoch:     4  batch:    30 [   300/600]  loss: 1.44380295  accuracy:  31.667%
# epoch:     4  batch:    40 [   400/600]  loss: 1.37479377  accuracy:  33.250%
# epoch:     4  batch:    50 [   500/600]  loss: 1.47541261  accuracy:  32.200%
# epoch:     4  batch:    60 [   600/600]  loss: 1.65859663  accuracy:  32.667%
# epoch:     5  batch:    10 [   100/600]  loss: 1.55615091  accuracy:  41.000%
# epoch:     5  batch:    20 [   200/600]  loss: 2.13466716  accuracy:  33.000%
# epoch:     5  batch:    30 [   300/600]  loss: 1.68381369  accuracy:  30.333%
# epoch:     5  batch:    40 [   400/600]  loss: 1.64622080  accuracy:  30.250%
# epoch:     5  batch:    50 [   500/600]  loss: 1.72194362  accuracy:  31.800%
# epoch:     5  batch:    60 [   600/600]  loss: 2.10853410  accuracy:  33.167%
# epoch:     6  batch:    10 [   100/600]  loss: 1.80239141  accuracy:  24.000%
# epoch:     6  batch:    20 [   200/600]  loss: 1.74284875  accuracy:  32.500%
# epoch:     6  batch:    30 [   300/600]  loss: 1.60375333  accuracy:  33.333%
# epoch:     6  batch:    40 [   400/600]  loss: 1.60839045  accuracy:  35.000%
# epoch:     6  batch:    50 [   500/600]  loss: 2.05414271  accuracy:  34.400%
# epoch:     6  batch:    60 [   600/600]  loss: 1.59710073  accuracy:  34.000%
# epoch:     7  batch:    10 [   100/600]  loss: 1.47007632  accuracy:  39.000%
# epoch:     7  batch:    20 [   200/600]  loss: 1.68768764  accuracy:  37.500%
# epoch:     7  batch:    30 [   300/600]  loss: 1.36842966  accuracy:  37.000%
# epoch:     7  batch:    40 [   400/600]  loss: 1.53827989  accuracy:  36.250%
# epoch:     7  batch:    50 [   500/600]  loss: 1.89045370  accuracy:  36.000%
# epoch:     7  batch:    60 [   600/600]  loss: 1.60560751  accuracy:  35.000%
# epoch:     8  batch:    10 [   100/600]  loss: 1.61590350  accuracy:  41.000%
# epoch:     8  batch:    20 [   200/600]  loss: 1.75565183  accuracy:  36.000%
# epoch:     8  batch:    30 [   300/600]  loss: 1.68545604  accuracy:  34.667%
# epoch:     8  batch:    40 [   400/600]  loss: 1.74176335  accuracy:  35.750%
# epoch:     8  batch:    50 [   500/600]  loss: 1.70527399  accuracy:  36.000%
# epoch:     8  batch:    60 [   600/600]  loss: 1.23799562  accuracy:  36.667%
# epoch:     9  batch:    10 [   100/600]  loss: 1.95313108  accuracy:  37.000%
# epoch:     9  batch:    20 [   200/600]  loss: 1.58572209  accuracy:  40.000%
# epoch:     9  batch:    30 [   300/600]  loss: 2.08138037  accuracy:  40.000%
# epoch:     9  batch:    40 [   400/600]  loss: 2.05038095  accuracy:  39.000%
# epoch:     9  batch:    50 [   500/600]  loss: 1.86778235  accuracy:  40.400%
# epoch:     9  batch:    60 [   600/600]  loss: 1.58383203  accuracy:  40.333%
# epoch:    10  batch:    10 [   100/600]  loss: 1.37673295  accuracy:  44.000%
# epoch:    45  batch:    10 [   100/600]  loss: 0.21596298  accuracy:  93.000%
# epoch:    45  batch:    20 [   200/600]  loss: 0.20591824  accuracy:  94.000%
# epoch:    45  batch:    30 [   300/600]  loss: 0.11686009  accuracy:  94.000%
# epoch:    45  batch:    40 [   400/600]  loss: 0.11451229  accuracy:  94.250%
# epoch:    45  batch:    50 [   500/600]  loss: 0.11039156  accuracy:  93.600%
# epoch:    45  batch:    60 [   600/600]  loss: 0.05046787  accuracy:  93.000%
# epoch:    46  batch:    10 [   100/600]  loss: 0.22581582  accuracy:  92.000%
# epoch:    46  batch:    20 [   200/600]  loss: 0.08123376  accuracy:  93.000%
# epoch:    46  batch:    30 [   300/600]  loss: 0.03018974  accuracy:  94.000%
# epoch:    46  batch:    40 [   400/600]  loss: 0.09800757  accuracy:  94.000%
# epoch:    46  batch:    50 [   500/600]  loss: 0.55650467  accuracy:  94.200%
# epoch:    46  batch:    60 [   600/600]  loss: 0.05388533  accuracy:  94.167%
# epoch:    47  batch:    10 [   100/600]  loss: 0.04645279  accuracy:  94.000%
# epoch:    47  batch:    20 [   200/600]  loss: 0.12717482  accuracy:  96.500%
# epoch:    47  batch:    30 [   300/600]  loss: 0.00505544  accuracy:  97.333%
# epoch:    47  batch:    40 [   400/600]  loss: 0.00025460  accuracy:  98.000%
# epoch:    47  batch:    50 [   500/600]  loss: 0.12358467  accuracy:  97.600%
# epoch:    47  batch:    60 [   600/600]  loss: 0.06687167  accuracy:  96.833%
# epoch:    48  batch:    10 [   100/600]  loss: 0.06560852  accuracy:  99.000%
# epoch:    48  batch:    20 [   200/600]  loss: 0.33181438  accuracy:  97.000%
# epoch:    48  batch:    30 [   300/600]  loss: 0.11045860  accuracy:  96.667%
# epoch:    48  batch:    40 [   400/600]  loss: 0.43951410  accuracy:  96.500%
# epoch:    48  batch:    50 [   500/600]  loss: 0.03630558  accuracy:  96.600%
# epoch:    48  batch:    60 [   600/600]  loss: 0.12918425  accuracy:  96.167%
# epoch:    49  batch:    10 [   100/600]  loss: 0.00560065  accuracy:  99.000%
# epoch:    49  batch:    20 [   200/600]  loss: 0.15667948  accuracy:  97.500%
# epoch:    49  batch:    30 [   300/600]  loss: 0.10406103  accuracy:  97.333%
# epoch:    49  batch:    40 [   400/600]  loss: 0.05071413  accuracy:  97.500%
# epoch:    49  batch:    50 [   500/600]  loss: 0.01980341  accuracy:  97.800%
# epoch:    49  batch:    60 [   600/600]  loss: 0.05060459  accuracy:  97.333%
#
# Duration: 1754 seconds

# %%
torch.save(model.state_dict(), 'CNN Model')

# %%
plt.plot(train_losses, label='training loss')
plt.plot(test_losses, label='validation loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.title('Loss at the end of each epoch')
plt.legend();

# %%
plt.plot([t.item()*100/599 for t in train_correct], label='training accuracy')
plt.plot([t.item()*100/400 for t in test_correct], label='validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.title('Accuracy at the end of each epoch')
plt.legend();
