# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models # add models to the list
from torchvision.utils import make_grid
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import os
from PIL import Image
from IPython.display import display

# Filter harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# try to get one of the images inside the file
with Image.open('melspectMask/train/rock/11.png') as im:
    display(im)
    print(im.size)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=432x288>
# (432, 288)

# %%
transform = transforms.ToTensor()
root ="melspectMask"

train_data = datasets.ImageFolder(os.path.join(root,"train"), transform= transform)
test_data = datasets.ImageFolder(os.path.join(root, "test"), transform = transform)

torch.manual_seed(30)

train_loader = DataLoader(train_data, batch_size=10,shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=False)

class_names = train_data.classes

# %%
class_names
# Out:
# ['blues',
#  'classical',
#  'country',
#  'disco',
#  'hiphop',
#  'jazz',
#  'metal',
#  'pop',
#  'reggae',
#  'rock']

# %%
len(train_data)
# Out:
# 2995

# %%
len(test_data)
# Out:
# 2000

# %%
for images, labels in train_loader:
    break
    

print('Labels: ', labels.numpy())
print('Class: ',*np.array([class_names[i] for i in labels]))

im = make_grid(images, nrow=5)
plt.figure(figsize=(10,4))
plt.imshow(np.transpose(im.numpy(),(1,2,0)))
# Out:
# Labels:  [4 5 3 6 3 4 6 1 4 6]
# Class:  hiphop jazz disco metal disco hiphop metal classical hiphop metal

# %%
images[0].shape
# Out:
# torch.Size([3, 288, 432])

# %%
print((((288-2)/2)-2)/2)
print(((430/2)-2)/2)
class ConvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5, 1)  
        self.conv2 = nn.Conv2d(6, 16, 3, 1)
        self.fc1 = nn.Linear(70*106*16, 120)   
        self.fc2 = nn.Linear(120,84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1,70*106*16) # flatten
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        return F.log_softmax(X, dim=1)
# Out:
# 70.5
# 106.5

# %%
model = ConvolutionalNetwork()
model
# Out:
# ConvolutionalNetwork(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=118720, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
for param in model.parameters():
    print(param.numel())
# Out:
# 450
# 6
# 864
# 16
# 14246400
# 120
# 10080
# 84
# 840
# 10

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.001) ## stochiastic gradient descent

# %%
import time
start_time = time.time()

epochs = 10

max_trn_batch = 800
max_tst_batch = 300

train_losses = []
test_losses = []
train_correct = []
test_correct = []

for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        
        # Limit the number of batches
        if b == max_trn_batch:
            break
        b+=1
       
        
        # Apply the model
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print interim results
        if b%10 == 0:
            print(f'epoch: {i:4}  batch: {b:4} [{10*b:6}/600]  loss: {loss.item():10.8f}  \
accuracy: {trn_corr.item()*100/(10*b):7.3f}%')

    train_losses.append(loss.data.item())
    train_correct.append(trn_corr)

    # Run the testing batches
    with torch.no_grad():
        for b, (X_test, y_test) in enumerate(test_loader):
            # Limit the number of batches
            if b == max_tst_batch:
                break

            # Apply the model
            y_val = model(X_test)

            # Tally the number of correct predictions
            predicted = torch.max(y_val.data, 1)[1] 
            tst_corr += (predicted == y_test).sum()

    loss = criterion(y_val, y_test)
    test_losses.append(loss.data.item())
    test_correct.append(tst_corr)

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:    0  batch:   10 [   100/600]  loss: 2.33954668  accuracy:   6.000%
# epoch:    0  batch:   20 [   200/600]  loss: 2.28743029  accuracy:   8.000%
# epoch:    0  batch:   30 [   300/600]  loss: 2.28667116  accuracy:   9.000%
# epoch:    0  batch:   40 [   400/600]  loss: 2.29978061  accuracy:   9.750%
# epoch:    0  batch:   50 [   500/600]  loss: 2.28723621  accuracy:   9.800%
# epoch:    0  batch:   60 [   600/600]  loss: 2.28668737  accuracy:   9.500%
# epoch:    0  batch:   70 [   700/600]  loss: 2.29012203  accuracy:   9.714%
# epoch:    0  batch:   80 [   800/600]  loss: 2.31802082  accuracy:   9.500%
# epoch:    0  batch:   90 [   900/600]  loss: 2.29714966  accuracy:   8.778%
# epoch:    0  batch:  100 [  1000/600]  loss: 2.28896809  accuracy:   8.500%
# epoch:    0  batch:  110 [  1100/600]  loss: 2.28664446  accuracy:   9.000%
# epoch:    0  batch:  120 [  1200/600]  loss: 2.29627776  accuracy:   9.000%
# epoch:    0  batch:  130 [  1300/600]  loss: 2.29066706  accuracy:   9.000%
# epoch:    0  batch:  140 [  1400/600]  loss: 2.30390692  accuracy:   9.071%
# epoch:    0  batch:  150 [  1500/600]  loss: 2.30174565  accuracy:   9.267%
# epoch:    0  batch:  160 [  1600/600]  loss: 2.28539824  accuracy:   9.375%
# epoch:    0  batch:  170 [  1700/600]  loss: 2.29583216  accuracy:   9.529%
# epoch:    0  batch:  180 [  1800/600]  loss: 2.28905177  accuracy:   9.500%
# epoch:    0  batch:  190 [  1900/600]  loss: 2.33926845  accuracy:   9.526%
# epoch:    0  batch:  200 [  2000/600]  loss: 2.29768562  accuracy:   9.500%
# epoch:    0  batch:  210 [  2100/600]  loss: 2.31103849  accuracy:   9.714%
# epoch:    0  batch:  220 [  2200/600]  loss: 2.30613279  accuracy:   9.682%
# epoch:    0  batch:  230 [  2300/600]  loss: 2.30701399  accuracy:   9.696%
# epoch:    0  batch:  240 [  2400/600]  loss: 2.26435447  accuracy:   9.792%
# epoch:    0  batch:  250 [  2500/600]  loss: 2.28931570  accuracy:   9.800%
# epoch:    0  batch:  260 [  2600/600]  loss: 2.30717754  accuracy:   9.731%
# epoch:    0  batch:  270 [  2700/600]  loss: 2.30911851  accuracy:   9.704%
# epoch:    0  batch:  280 [  2800/600]  loss: 2.30645847  accuracy:   9.786%
# epoch:    0  batch:  290 [  2900/600]  loss: 2.29142404  accuracy:   9.759%
# epoch:    0  batch:  300 [  3000/600]  loss: 2.31634331  accuracy:   9.767%
# epoch:    1  batch:   10 [   100/600]  loss: 2.30371714  accuracy:  16.000%
# epoch:    1  batch:   20 [   200/600]  loss: 2.29696703  accuracy:  12.500%
# epoch:    1  batch:   30 [   300/600]  loss: 2.29017329  accuracy:  12.000%
# epoch:    1  batch:   40 [   400/600]  loss: 2.31098175  accuracy:  12.500%
# epoch:    1  batch:   50 [   500/600]  loss: 2.29785442  accuracy:  12.600%
# epoch:    1  batch:   60 [   600/600]  loss: 2.30575418  accuracy:  11.833%
# epoch:    1  batch:   70 [   700/600]  loss: 2.30818033  accuracy:  11.429%
# epoch:    1  batch:   80 [   800/600]  loss: 2.29503965  accuracy:  11.500%
# epoch:    1  batch:   90 [   900/600]  loss: 2.31307936  accuracy:  11.000%
# epoch:    1  batch:  100 [  1000/600]  loss: 2.27796054  accuracy:  11.000%
# epoch:    1  batch:  110 [  1100/600]  loss: 2.32012224  accuracy:  10.727%
# epoch:    1  batch:  120 [  1200/600]  loss: 2.30020666  accuracy:  10.583%
# epoch:    1  batch:  130 [  1300/600]  loss: 2.31084871  accuracy:  10.385%
# epoch:    1  batch:  140 [  1400/600]  loss: 2.32105494  accuracy:  10.143%
# epoch:    1  batch:  150 [  1500/600]  loss: 2.29889536  accuracy:  10.400%
# epoch:    1  batch:  160 [  1600/600]  loss: 2.28656960  accuracy:  10.250%
# epoch:    1  batch:  170 [  1700/600]  loss: 2.28854227  accuracy:  10.000%
# epoch:    1  batch:  180 [  1800/600]  loss: 2.30395746  accuracy:   9.778%
# epoch:    1  batch:  190 [  1900/600]  loss: 2.29578447  accuracy:   9.789%
# epoch:    1  batch:  200 [  2000/600]  loss: 2.30720401  accuracy:   9.700%
# epoch:    1  batch:  210 [  2100/600]  loss: 2.31220841  accuracy:   9.857%
# epoch:    1  batch:  220 [  2200/600]  loss: 2.30106783  accuracy:   9.727%
# epoch:    1  batch:  230 [  2300/600]  loss: 2.30304527  accuracy:   9.783%
# epoch:    1  batch:  240 [  2400/600]  loss: 2.31853175  accuracy:   9.625%
# epoch:    1  batch:  250 [  2500/600]  loss: 2.30158067  accuracy:   9.720%
# epoch:    1  batch:  260 [  2600/600]  loss: 2.29996276  accuracy:   9.654%
# epoch:    1  batch:  270 [  2700/600]  loss: 2.29804277  accuracy:   9.593%
# epoch:    1  batch:  280 [  2800/600]  loss: 2.30477071  accuracy:   9.393%
# epoch:    1  batch:  290 [  2900/600]  loss: 2.30410910  accuracy:   9.483%
# epoch:    1  batch:  300 [  3000/600]  loss: 2.29582906  accuracy:   9.367%
# epoch:    2  batch:   10 [   100/600]  loss: 2.31079054  accuracy:   9.000%
# epoch:    2  batch:   20 [   200/600]  loss: 2.30355120  accuracy:  11.500%
# epoch:    2  batch:   30 [   300/600]  loss: 2.29779816  accuracy:   9.667%
# epoch:    2  batch:   40 [   400/600]  loss: 2.30852056  accuracy:  10.000%
# epoch:    2  batch:   50 [   500/600]  loss: 2.30147338  accuracy:  10.000%
# epoch:    2  batch:   60 [   600/600]  loss: 2.30439544  accuracy:  10.500%
# epoch:    2  batch:   70 [   700/600]  loss: 2.31262922  accuracy:  10.571%
# epoch:    2  batch:   80 [   800/600]  loss: 2.29901171  accuracy:  10.500%
# epoch:    2  batch:   90 [   900/600]  loss: 2.30164194  accuracy:  10.667%
# epoch:    2  batch:  100 [  1000/600]  loss: 2.29925394  accuracy:  10.600%
# epoch:    2  batch:  110 [  1100/600]  loss: 2.28870273  accuracy:  10.545%
# epoch:    2  batch:  120 [  1200/600]  loss: 2.29731679  accuracy:  10.750%
# epoch:    2  batch:  130 [  1300/600]  loss: 2.30879188  accuracy:  10.538%
# epoch:    2  batch:  140 [  1400/600]  loss: 2.30711007  accuracy:  10.571%
# epoch:    2  batch:  150 [  1500/600]  loss: 2.30377293  accuracy:  10.733%
# epoch:    2  batch:  160 [  1600/600]  loss: 2.31017923  accuracy:  10.500%
# epoch:    2  batch:  170 [  1700/600]  loss: 2.29577279  accuracy:  10.765%
# epoch:    2  batch:  180 [  1800/600]  loss: 2.30249166  accuracy:  10.778%
# epoch:    2  batch:  190 [  1900/600]  loss: 2.29937983  accuracy:  10.895%
# epoch:    2  batch:  200 [  2000/600]  loss: 2.29888105  accuracy:  10.750%
# epoch:    2  batch:  210 [  2100/600]  loss: 2.32023668  accuracy:  10.429%
# epoch:    2  batch:  220 [  2200/600]  loss: 2.30861044  accuracy:  10.227%
# epoch:    2  batch:  230 [  2300/600]  loss: 2.30147934  accuracy:  10.348%
# epoch:    2  batch:  240 [  2400/600]  loss: 2.30249548  accuracy:  10.375%
# epoch:    2  batch:  250 [  2500/600]  loss: 2.31267405  accuracy:  10.400%
# epoch:    2  batch:  260 [  2600/600]  loss: 2.31442475  accuracy:  10.192%
# epoch:    2  batch:  270 [  2700/600]  loss: 2.29621983  accuracy:  10.000%
# epoch:    2  batch:  280 [  2800/600]  loss: 2.30408406  accuracy:  10.000%
# epoch:    2  batch:  290 [  2900/600]  loss: 2.30566192  accuracy:  10.034%
# epoch:    2  batch:  300 [  3000/600]  loss: 2.30731702  accuracy:   9.933%
# epoch:    3  batch:   10 [   100/600]  loss: 2.30507326  accuracy:  14.000%
# epoch:    3  batch:   20 [   200/600]  loss: 2.30281711  accuracy:  12.500%
# epoch:    3  batch:   30 [   300/600]  loss: 2.30402994  accuracy:  10.667%
# epoch:    3  batch:   40 [   400/600]  loss: 2.29905248  accuracy:   9.500%
# epoch:    3  batch:   50 [   500/600]  loss: 2.29901528  accuracy:   9.800%
# epoch:    3  batch:   60 [   600/600]  loss: 2.29719782  accuracy:   9.167%
# epoch:    3  batch:   70 [   700/600]  loss: 2.30684638  accuracy:   9.000%
# epoch:    3  batch:   80 [   800/600]  loss: 2.30298615  accuracy:   8.500%
# epoch:    3  batch:   90 [   900/600]  loss: 2.30979085  accuracy:   8.333%
# epoch:    3  batch:  100 [  1000/600]  loss: 2.30141521  accuracy:   8.600%
# epoch:    3  batch:  110 [  1100/600]  loss: 2.30935287  accuracy:   8.727%
# epoch:    3  batch:  120 [  1200/600]  loss: 2.31612468  accuracy:   8.583%
# epoch:    3  batch:  130 [  1300/600]  loss: 2.31413531  accuracy:   8.615%
# epoch:    3  batch:  140 [  1400/600]  loss: 2.30044937  accuracy:   8.857%
# epoch:    3  batch:  150 [  1500/600]  loss: 2.29807615  accuracy:   9.067%
# epoch:    3  batch:  160 [  1600/600]  loss: 2.30961418  accuracy:   8.812%
# epoch:    3  batch:  170 [  1700/600]  loss: 2.29887342  accuracy:   9.000%
# epoch:    3  batch:  180 [  1800/600]  loss: 2.30123973  accuracy:   8.833%
# epoch:    3  batch:  190 [  1900/600]  loss: 2.30424547  accuracy:   8.947%
# epoch:    3  batch:  200 [  2000/600]  loss: 2.30397606  accuracy:   8.950%
# epoch:    3  batch:  210 [  2100/600]  loss: 2.29965448  accuracy:   8.905%
# epoch:    3  batch:  220 [  2200/600]  loss: 2.30490184  accuracy:   8.955%
# epoch:    3  batch:  230 [  2300/600]  loss: 2.30228567  accuracy:   8.739%
# epoch:    3  batch:  240 [  2400/600]  loss: 2.29820204  accuracy:   8.750%
# epoch:    3  batch:  250 [  2500/600]  loss: 2.29542303  accuracy:   8.840%
# epoch:    3  batch:  260 [  2600/600]  loss: 2.28643036  accuracy:   9.077%
# epoch:    3  batch:  270 [  2700/600]  loss: 2.30362034  accuracy:   9.074%
# epoch:    3  batch:  280 [  2800/600]  loss: 2.30081129  accuracy:   9.071%
# epoch:    3  batch:  290 [  2900/600]  loss: 2.30330801  accuracy:   8.862%
# epoch:    3  batch:  300 [  3000/600]  loss: 2.29709363  accuracy:   8.833%
# epoch:    4  batch:   10 [   100/600]  loss: 2.29896617  accuracy:   8.000%
# epoch:    4  batch:   20 [   200/600]  loss: 2.29953527  accuracy:  12.500%
# epoch:    4  batch:   30 [   300/600]  loss: 2.29695868  accuracy:  10.667%
# epoch:    4  batch:   40 [   400/600]  loss: 2.30826426  accuracy:  10.250%
# epoch:    4  batch:   50 [   500/600]  loss: 2.30038500  accuracy:  10.200%
# epoch:    4  batch:   60 [   600/600]  loss: 2.30340290  accuracy:   9.500%
# epoch:    4  batch:   70 [   700/600]  loss: 2.30004954  accuracy:   9.429%
# epoch:    4  batch:   80 [   800/600]  loss: 2.30163884  accuracy:   9.375%
# epoch:    4  batch:   90 [   900/600]  loss: 2.30831766  accuracy:   9.222%
# epoch:    4  batch:  100 [  1000/600]  loss: 2.29184771  accuracy:   9.300%
# epoch:    4  batch:  110 [  1100/600]  loss: 2.30347776  accuracy:   9.273%
# epoch:    4  batch:  120 [  1200/600]  loss: 2.31132174  accuracy:   9.833%
# epoch:    4  batch:  130 [  1300/600]  loss: 2.29919505  accuracy:   9.923%
# epoch:    4  batch:  140 [  1400/600]  loss: 2.30757976  accuracy:  10.000%
# epoch:    4  batch:  150 [  1500/600]  loss: 2.31190014  accuracy:   9.667%
# epoch:    4  batch:  160 [  1600/600]  loss: 2.30410576  accuracy:   9.500%
# epoch:    4  batch:  170 [  1700/600]  loss: 2.30991220  accuracy:   9.706%
# epoch:    4  batch:  180 [  1800/600]  loss: 2.30528593  accuracy:   9.778%
# epoch:    4  batch:  190 [  1900/600]  loss: 2.31433964  accuracy:   9.947%
# epoch:    4  batch:  200 [  2000/600]  loss: 2.29444337  accuracy:  10.100%
# epoch:    4  batch:  210 [  2100/600]  loss: 2.30928206  accuracy:   9.762%
# epoch:    4  batch:  220 [  2200/600]  loss: 2.30646372  accuracy:   9.682%
# epoch:    4  batch:  230 [  2300/600]  loss: 2.30608177  accuracy:   9.565%
# epoch:    4  batch:  240 [  2400/600]  loss: 2.30384517  accuracy:   9.750%
# epoch:    4  batch:  250 [  2500/600]  loss: 2.30053091  accuracy:   9.760%
# epoch:    4  batch:  260 [  2600/600]  loss: 2.30291653  accuracy:   9.769%
# epoch:    4  batch:  270 [  2700/600]  loss: 2.30347133  accuracy:   9.593%
# epoch:    4  batch:  280 [  2800/600]  loss: 2.30679011  accuracy:   9.679%
# epoch:    4  batch:  290 [  2900/600]  loss: 2.30866575  accuracy:   9.552%
# epoch:    4  batch:  300 [  3000/600]  loss: 2.31375837  accuracy:   9.600%
#
# Duration: 879 seconds

# %%
torch.save(model.state_dict(), 'CNN Model')

# %%
print(train_losses)
plt.plot(train_losses)
plt.plot(test_losses, label='validation loss')
plt.title('Loss at the end of each epoch')
plt.legend()
# Out:
# [2.316343307495117, 2.2958290576934814, 2.307317018508911, 2.297093629837036, 2.313758373260498]

# %%
plt.plot(train_correct)
plt.plot(test_correct)
